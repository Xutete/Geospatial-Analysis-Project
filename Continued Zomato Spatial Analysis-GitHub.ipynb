# %%
# First, Let's Import the "Libraries" -
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#To avoid displaying the FutureWarning:
import warnings
warnings.filterwarnings(action='ignore')

# %%
# Reading the Data -
df_Zomato = pd.read_csv('zomato.csv')
df_Zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
#Checking "Missing Values" against each Features -
df_Zomato.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
#Now, Let's just "drop" All those Missing Values from 'location' Feature -

df_Zomato.dropna(axis = 'index', subset = ['location'], inplace = True)

# %%
#Now, Cross-Checking the Missing Values -
df_Zomato.isnull().sum()

#Now, will see we don't have any NaN Values or Missing Values in this "location" Column anymore.
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7754
# votes                              0
# phone                           1187
# location                           0
# rest_type                        206
# dish_liked                     28057
# cuisines                          24
# approx_cost(for two people)      325
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
#Let's Check 'unique' Values of 'location' Feature -

df_Zomato['location'].unique()
# Out:
# array(['Banashankari', 'Basavanagudi', 'Mysore Road', 'Jayanagar',
#        'Kumaraswamy Layout', 'Rajarajeshwari Nagar', 'Vijay Nagar',
#        'Uttarahalli', 'JP Nagar', 'South Bangalore', 'City Market',
#        'Nagarbhavi', 'Bannerghatta Road', 'BTM', 'Kanakapura Road',
#        'Bommanahalli', 'CV Raman Nagar', 'Electronic City', 'HSR',
#        'Marathahalli', 'Sarjapur Road', 'Wilson Garden', 'Shanti Nagar',
#        'Koramangala 5th Block', 'Koramangala 8th Block', 'Richmond Road',
#        'Koramangala 7th Block', 'Jalahalli', 'Koramangala 4th Block',
#        'Bellandur', 'Whitefield', 'East Bangalore', 'Old Airport Road',
#        'Indiranagar', 'Koramangala 1st Block', 'Frazer Town', 'RT Nagar',
#        'MG Road', 'Brigade Road', 'Lavelle Road', 'Church Street',
#        'Ulsoor', 'Residency Road', 'Shivajinagar', 'Infantry Road',
#        'St. Marks Road', 'Cunningham Road', 'Race Course Road',
#        'Commercial Street', 'Vasanth Nagar', 'HBR Layout', 'Domlur',
#        'Ejipura', 'Jeevan Bhima Nagar', 'Old Madras Road', 'Malleshwaram',
#        'Seshadripuram', 'Kammanahalli', 'Koramangala 6th Block',
#        'Majestic', 'Langford Town', 'Central Bangalore', 'Sanjay Nagar',
#        'Brookefield', 'ITPL Main Road, Whitefield',
#        'Varthur Main Road, Whitefield', 'KR Puram',
#        'Koramangala 2nd Block', 'Koramangala 3rd Block', 'Koramangala',
#        'Hosur Road', 'Rajajinagar', 'Banaswadi', 'North Bangalore',
#        'Nagawara', 'Hennur', 'Kalyan Nagar', 'New BEL Road', 'Jakkur',
#        'Rammurthy Nagar', 'Thippasandra', 'Kaggadasapura', 'Hebbal',
#        'Kengeri', 'Sankey Road', 'Sadashiv Nagar', 'Basaveshwara Nagar',
#        'Yeshwantpur', 'West Bangalore', 'Magadi Road', 'Yelahanka',
#        'Sahakara Nagar', 'Peenya'], dtype=object)

# %%
#Checking the Length of our Unique Locations -
len(df_Zomato['location'].unique())
# Out:
# 93

# %%
#Let's identify the Data which having/contains "Bangalore" in the given data -
location_with_Bangalore = df_Zomato.loc[df_Zomato['location'].str.contains("Bangalore")]['location']
location_with_Bangalore

#Here, We can see that, We have Total of 179 Records having "Bangalore" word.
# Out:
# 355      South Bangalore
# 629      South Bangalore
# 830      South Bangalore
# 1342     South Bangalore
# 1347     South Bangalore
#               ...
# 50674     East Bangalore
# 50818     East Bangalore
# 51002     East Bangalore
# 51213     East Bangalore
# 51234     East Bangalore
# Name: location, Length: 179, dtype: object

# %%
#Now, Let's process this data -
def data_preprocessing(data):
    data = data.replace('Bangalore', '').strip()
    return data

# %%
#Now, Let's apply this Function to this particular Data -
location_with_Bangalore.apply(data_preprocessing)

#Now, We can see, All this data is processed as per the requirement. Hence, We can apply this same Function to our Original 
#'location' Feature/Column to get the desired result.
# Out:
# 355      South
# 629      South
# 830      South
# 1342     South
# 1347     South
#          ...
# 50674     East
# 50818     East
# 51002     East
# 51213     East
# 51234     East
# Name: location, Length: 179, dtype: object

# %%
#Now, Let's apply this Function to our whole/entire Data -
df_Zomato['location (Processed)'] = df_Zomato['location'].apply(data_preprocessing)

#Now, We can see, All this data is processed as per the requirement.

# %%
#Let's cross-check What we have got into "location (Processed)" Column/Feature -
df_Zomato['location (Processed)']

#Now, We can see, All this data is processed as per the requirement.
# Out:
# 0                      Banashankari
# 1                      Banashankari
# 2                      Banashankari
# 3                      Banashankari
# 4                      Basavanagudi
#                     ...
# 51712                    Whitefield
# 51713                    Whitefield
# 51714                    Whitefield
# 51715    ITPL Main Road, Whitefield
# 51716    ITPL Main Road, Whitefield
# Name: location (Processed), Length: 51696, dtype: object

# %%
#Now, Let's move-on to do further pre-processing -
myList = []
for i in df_Zomato['location (Processed)']:
    i = i + ' Bangalore'
    myList.append(i)

# %%
#Cross-Check What we've got:
myList
# Out:
# ['Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Mysore Road Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Rajarajeshwari Nagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Vijay Nagar Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Vijay Nagar Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Mysore Road Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Uttarahalli Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'JP Nagar Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'JP Nagar Bangalore',
#  'Mysore Road Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Mysore Road Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Uttarahalli Bangalore',
#  'Jayanagar Bangalore',
#  'Uttarahalli Bangalore',
#  'Vijay Nagar Bangalore',
#  'Mysore Road Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Mysore Road Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Vijay Nagar Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Uttarahalli Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Uttarahalli Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Uttarahalli Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Rajarajeshwari Nagar Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Mysore Road Bangalore',
#  'South Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Uttarahalli Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Vijay Nagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Uttarahalli Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Uttarahalli Bangalore',
#  'JP Nagar Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'City Market Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Mysore Road Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Uttarahalli Bangalore',
#  'Jayanagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Banashankari Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Jayanagar Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'JP Nagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'South Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Mysore Road Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Mysore Road Bangalore',
#  'Jayanagar Bangalore',
#  'Mysore Road Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Uttarahalli Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Mysore Road Bangalore',
#  'Basavanagudi Bangalore',
#  'Mysore Road Bangalore',
#  'Basavanagudi Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Mysore Road Bangalore',
#  'Mysore Road Bangalore',
#  'South Bangalore',
#  'Nagarbhavi Bangalore',
#  'Basavanagudi Bangalore',
#  'Kumaraswamy Layout Bangalore',
#  'Mysore Road Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Mysore Road Bangalore',
#  'Mysore Road Bangalore',
#  'Basavanagudi Bangalore',
#  'Mysore Road Bangalore',
#  'Basavanagudi Bangalore',
#  'Mysore Road Bangalore',
#  'Uttarahalli Bangalore',
#  'Jayanagar Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Basavanagudi Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Banashankari Bangalore',
#  'Basavanagudi Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'BTM Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'BTM Bangalore',
#  'BTM Bangalore',
#  'BTM Bangalore',
#  'BTM Bangalore',
#  'Bannerghatta Road Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'BTM Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'BTM Bangalore',
#  'BTM Bangalore',
#  'BTM Bangalore',
#  'BTM Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'Bannerghatta Road Bangalore',
#  'BTM Bangalore',
#  'BTM Bangalore',
#  'Bannerghatta Road Bangalore',
#  'BTM Bangalore',
#  'BTM Bangalore',
#  'JP Nagar Bangalore',
#  'Bannerghatta Road Bangalore',
#  'BTM Bangalore',
#  'BTM Bangalore',
#  'Bannerghatta Road Bangalore',
#  'BTM Bangalore',
#  'BTM Bangalore',
#  'Bannerghatta Road Bangalore',
#  'BTM Bangalore',
#  'JP Nagar Bangalore',
#  'BTM Bangalore',
#  'Bannerghatta Road Bangalore',
#  'JP Nagar Bangalore',
#  'Bannerghatta Road Bangalore',
#  'JP Nagar Bangalore',
#  'BTM Bangalore',
#  'BTM Bangalore',
#  'Jayanagar Bangalore',
#  'BTM Bangalore',
#  'Bannerghatta Road Bangalore',
#  'JP Nagar Bangalore',
#  'Bannerghatta Road Bangalore',
#  'BTM Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'JP Nagar Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'BTM Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'Bannerghatta Road Bangalore',
#  'JP Nagar Bangalore',
#  'Bannerghatta Road Bangalore',
#  'BTM Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'Bannerghatta Road Bangalore',
#  'BTM Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'JP Nagar Bangalore',
#  'Bannerghatta Road Bangalore',
#  'BTM Bangalore',
#  'JP Nagar Bangalore',
#  'Jayanagar Bangalore',
#  'Kanakapura Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'Bannerghatta Road Bangalore',
#  'BTM Bangalore',
#  'JP Nagar Bangalore',
#  'JP Nagar Bangalore',
#  'BTM Bangalore',
#  ...]

# %%
#Now, Let's pass this List to our DataFrame feature -
    
df_Zomato['location (Processed)'] = myList

# %%
#Cross-Check What we've got:
df_Zomato['location (Processed)']
# Out:
# 0                      Banashankari Bangalore
# 1                      Banashankari Bangalore
# 2                      Banashankari Bangalore
# 3                      Banashankari Bangalore
# 4                      Basavanagudi Bangalore
#                          ...
# 51712                    Whitefield Bangalore
# 51713                    Whitefield Bangalore
# 51714                    Whitefield Bangalore
# 51715    ITPL Main Road, Whitefield Bangalore
# 51716    ITPL Main Road, Whitefield Bangalore
# Name: location (Processed), Length: 51696, dtype: object

# %%
#Now, Let's check the "unique" Locations in this "location" Column.

df_Zomato['location (Processed)'].unique()
# Out:
# array(['Banashankari Bangalore', 'Basavanagudi Bangalore',
#        'Mysore Road Bangalore', 'Jayanagar Bangalore',
#        'Kumaraswamy Layout Bangalore', 'Rajarajeshwari Nagar Bangalore',
#        'Vijay Nagar Bangalore', 'Uttarahalli Bangalore',
#        'JP Nagar Bangalore', 'South Bangalore', 'City Market Bangalore',
#        'Nagarbhavi Bangalore', 'Bannerghatta Road Bangalore',
#        'BTM Bangalore', 'Kanakapura Road Bangalore',
#        'Bommanahalli Bangalore', 'CV Raman Nagar Bangalore',
#        'Electronic City Bangalore', 'HSR Bangalore',
#        'Marathahalli Bangalore', 'Sarjapur Road Bangalore',
#        'Wilson Garden Bangalore', 'Shanti Nagar Bangalore',
#        'Koramangala 5th Block Bangalore',
#        'Koramangala 8th Block Bangalore', 'Richmond Road Bangalore',
#        'Koramangala 7th Block Bangalore', 'Jalahalli Bangalore',
#        'Koramangala 4th Block Bangalore', 'Bellandur Bangalore',
#        'Whitefield Bangalore', 'East Bangalore',
#        'Old Airport Road Bangalore', 'Indiranagar Bangalore',
#        'Koramangala 1st Block Bangalore', 'Frazer Town Bangalore',
#        'RT Nagar Bangalore', 'MG Road Bangalore',
#        'Brigade Road Bangalore', 'Lavelle Road Bangalore',
#        'Church Street Bangalore', 'Ulsoor Bangalore',
#        'Residency Road Bangalore', 'Shivajinagar Bangalore',
#        'Infantry Road Bangalore', 'St. Marks Road Bangalore',
#        'Cunningham Road Bangalore', 'Race Course Road Bangalore',
#        'Commercial Street Bangalore', 'Vasanth Nagar Bangalore',
#        'HBR Layout Bangalore', 'Domlur Bangalore', 'Ejipura Bangalore',
#        'Jeevan Bhima Nagar Bangalore', 'Old Madras Road Bangalore',
#        'Malleshwaram Bangalore', 'Seshadripuram Bangalore',
#        'Kammanahalli Bangalore', 'Koramangala 6th Block Bangalore',
#        'Majestic Bangalore', 'Langford Town Bangalore',
#        'Central Bangalore', 'Sanjay Nagar Bangalore',
#        'Brookefield Bangalore', 'ITPL Main Road, Whitefield Bangalore',
#        'Varthur Main Road, Whitefield Bangalore', 'KR Puram Bangalore',
#        'Koramangala 2nd Block Bangalore',
#        'Koramangala 3rd Block Bangalore', 'Koramangala Bangalore',
#        'Hosur Road Bangalore', 'Rajajinagar Bangalore',
#        'Banaswadi Bangalore', 'North Bangalore', 'Nagawara Bangalore',
#        'Hennur Bangalore', 'Kalyan Nagar Bangalore',
#        'New BEL Road Bangalore', 'Jakkur Bangalore',
#        'Rammurthy Nagar Bangalore', 'Thippasandra Bangalore',
#        'Kaggadasapura Bangalore', 'Hebbal Bangalore', 'Kengeri Bangalore',
#        'Sankey Road Bangalore', 'Sadashiv Nagar Bangalore',
#        'Basaveshwara Nagar Bangalore', 'Yeshwantpur Bangalore',
#        'West Bangalore', 'Magadi Road Bangalore', 'Yelahanka Bangalore',
#        'Sahakara Nagar Bangalore', 'Peenya Bangalore'], dtype=object)

# %%
#Checking the Length of our Unique Locations -
len(df_Zomato['location (Processed)'].unique())
# Out:
# 93

# %%
#Now, Let's deep dive into "Geo-graphical" Analysis -

df_locations = pd.DataFrame()
df_locations['Name'] = df_Zomato['location (Processed)'].unique()
df_locations.head()
#Here, We will see, in this "df_locations" DataFrame, We have each and every 'unique' Locations.
# Out:
#                            Name
# 0        Banashankari Bangalore
# 1        Basavanagudi Bangalore
# 2         Mysore Road Bangalore
# 3           Jayanagar Bangalore
# 4  Kumaraswamy Layout Bangalore

# %%
#Now, Let's install our "Geopy" Library.
    
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\lksh & deeps\appdata\local\programs\python\python39\lib\site-packages (2.2.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\lksh & deeps\appdata\local\programs\python\python39\lib\site-packages (from geopy) (1.52)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\lksh & deeps\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
#Each and Every 'geolocation' Service has its own Class in 'geographical Python', which is my 'geopy'.
#So, Very First, Let's import them and Set Connection to this "Open Street Map".

import geopy
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent = 'myapplications', timeout = None)

# %%
#Extract Latitudes and Logitudes for each of the Locations of Bangalore.

Lat = []
Long = []
    
for location in df_locations['Name']:
    location = geolocator.geocode(location)
    
    if location is None: 
        Lat.append(np.nan)
        Long.append(np.nan)
    else:
        Lat.append(location.latitude)
        Long.append(location.longitude)

# %%
# Now, Add these ('Latitude' & 'Longitude') Columns to DataFrame -
df_locations['Latitude'] = Lat
df_locations['Longitude'] = Long

# %%
#Now, Let's Check What we've got in our DataFrame -
df_locations.head()

#So, Here we will see all the 'latitude' and 'longitude' values we've obtained with respect to each and every location.
# Out:
#                            Name   Latitude  Longitude
# 0        Banashankari Bangalore  12.915221  77.573598
# 1        Basavanagudi Bangalore  12.941726  77.575502
# 2         Mysore Road Bangalore  12.959752  77.556129
# 3           Jayanagar Bangalore  12.929273  77.582423
# 4  Kumaraswamy Layout Bangalore  12.908149  77.555318

# %%
#Checking How many No. of Locations we have -
df_locations.shape

#So, it is basically saying me that I have around "93" Locations in Bangalore.
# Out:
# (93, 3)

# %%
#Now, Let's get the Top Locations -
        
rest_Locations = df_Zomato['location (Processed)'].value_counts().reset_index()
rest_Locations
# Out:
#                               index  location (Processed)
# 0                     BTM Bangalore                  5124
# 1                     HSR Bangalore                  2523
# 2   Koramangala 5th Block Bangalore                  2504
# 3                JP Nagar Bangalore                  2235
# 4              Whitefield Bangalore                  2144
# ..                              ...                   ...
# 88                   West Bangalore                     6
# 89              Yelahanka Bangalore                     6
# 90                 Jakkur Bangalore                     3
# 91   Rajarajeshwari Nagar Bangalore                     2
# 92                 Peenya Bangalore                     1
#
# [93 rows x 2 columns]

# %%
#Now, Let's pre-process this DataFrame -

rest_Locations.columns = ['Name', 'Count']
rest_Locations.head()
# Out:
#                               Name  Count
# 0                    BTM Bangalore   5124
# 1                    HSR Bangalore   2523
# 2  Koramangala 5th Block Bangalore   2504
# 3               JP Nagar Bangalore   2235
# 4             Whitefield Bangalore   2144

# %%
#Now, Let's 'Combine'/'Merge' both our DataFrame -
    #So, Very 1st one is my "rest_Locations" and the 2nd one is my "df_locations".
    
Restaurant_Locations = rest_Locations.merge(right = df_locations, on = 'Name', how = 'left').dropna()
Restaurant_Locations.head()
# Out:
#                               Name  Count   Latitude  Longitude
# 0                    BTM Bangalore   5124  12.911276  77.604565
# 1                    HSR Bangalore   2523  12.911623  77.638862
# 2  Koramangala 5th Block Bangalore   2504  12.928081  77.630720
# 3               JP Nagar Bangalore   2235  12.907251  77.578271
# 4             Whitefield Bangalore   2144  12.969637  77.749745

# %% [markdown]
# # Use Case 1 -
# Q1. Generate/Create a BaseMap of Bangalore.

# %%
#Q1. Generate BaseMap of Bangalore. -->
    
#To Create "Map" or To Create "Interactive Maps", we need "folium" Library.

# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\lksh & deeps\appdata\local\programs\python\python39\lib\site-packages (0.12.1)
# Requirement already satisfied: requests in c:\users\lksh & deeps\appdata\local\programs\python\python39\lib\site-packages (from folium) (2.26.0)
# Requirement already satisfied: branca>=0.3.0 in c:\users\lksh & deeps\appdata\local\programs\python\python39\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\lksh & deeps\appdata\local\programs\python\python39\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in c:\users\lksh & deeps\appdata\local\programs\python\python39\lib\site-packages (from folium) (1.21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lksh & deeps\appdata\local\programs\python\python39\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lksh & deeps\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lksh & deeps\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lksh & deeps\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lksh & deeps\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (2021.5.30)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\lksh & deeps\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
#Then, we have to Import our 'folium' Library with HeatMap -

import folium
from folium.plugins import HeatMap

# %%
#Now, Let's Create a 'BaseMap' -
    
def generateBaseMap(default_location = [12.928081, 77.630720], default_zoom_start = 12):
    baseMap = folium.Map(location = default_location, zoom_start = default_zoom_start)
#Now, Whatever baseMap it will return me, I have to 'return' it.
    return baseMap

# %%
#Now, Call our 'Function' with "default_location" and "default_zoom_start" will be my Parameters.

baseMap = generateBaseMap()

# %%
#Then, Call the 'baseMap' -
baseMap

#So, this is our 'baseMap' of Bangalore.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_764405d847314ca7aa3cc797d00e3c90%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_764405d847314ca7aa3cc797d00e3c90%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_764405d847314ca7aa3cc797d00e3c90%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_764405d847314ca7aa3cc797d00e3c90%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B12.928081%2C%2077.63072%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
#Q2. Create a HeatMap of Restaurants in Bangalore.

HeatMap(Restaurant_Locations[['Latitude', 'Longitude', 'Count']], zoom = 20).add_to(baseMap)

# %%
#Then, Call our 'baseMap' -
baseMap

#So, from this Visualization, we can see All the Restaurants are Located over here.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_764405d847314ca7aa3cc797d00e3c90%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_764405d847314ca7aa3cc797d00e3c90%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_764405d847314ca7aa3cc797d00e3c90%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_764405d847314ca7aa3cc797d00e3c90%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %% [markdown]
# **Conclusion -**
# - So, To make an ***inferences*** from this **HeatMap**, it is damn clear that We have ***very High Clutter/Density of Restaurants*** in **"South-East" Bangalore** Area. It means ***very High Number of Restaurants*** are there.
# - On the other hand, As we move away from **"Central" Bangalore** region, will figure-out, We have ***Less Number of Restaurants***.
# - In short, From this **HeatMap**, We can see that ***Most of the Restaurants*** are ***situated*** in the **"South-East Bangalore Area"**.

# %% [markdown]
# ### "Marker Cluster Analysis" on our Zomato Dataset -

# %%
#Now, From our 'folium' Library, we have to import FastMarkerCluster plugins -

from folium.plugins import FastMarkerCluster

# %%
#Q3. Create a HeatMap of Restaurants in Bangalore: Marker Cluster Map -->
  
FastMarkerCluster(Restaurant_Locations[['Latitude', 'Longitude', 'Count']], zoom = 20).add_to(baseMap)

# %%
#Then, Call the 'baseMap' -
baseMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_764405d847314ca7aa3cc797d00e3c90%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20 ...

# %% [markdown]
# **Conclusion -** Marker Cluster Map
# - So, To make an ***inferences*** from this **HeatMap**, it is damn clear that We have ***very High Clutter/Density of Restaurants*** in **"South-East" Bangalore** Area. It means ***very High Number of Restaurants*** are there.
# - On the other hand, As we move away from **"Central" Bangalore** region, will figure-out, We have ***Less Number of Restaurants***.
# - In short, From this **HeatMap**, We can see that ***Most of the Restaurants*** are ***situated*** in the **"South-East Bangalore Area"**.

# %%
df_Zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)    location (Processed)
# 0          Buffet    Banashankari  Banashankari Bangalore
# 1          Buffet    Banashankari  Banashankari Bangalore
# 2          Buffet    Banashankari  Banashankari Bangalore
# 3          Buffet    Banashankari  Banashankari Bangalore
# 4          Buffet    Banashankari  Basavanagudi Bangalore

# %%
#Q4. Now, Let's Analyze where are the Restaurants with Most Average Ratings OR We can say, With High Average Rating?

#Let's Check 'unique' Values of 'rate' Feature -
df_Zomato['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
#So, 1st of All, Let's "drop" these "NaN" Values.
    
df_Zomato.dropna(axis = 'index', subset = ['rate'], inplace = True)

# %%
#Now, Let's Cross-check the data -
df_Zomato['rate'].unique()

#It will remove all our 'nan' Values in "rate" Column.
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
#Next, simply "Drop" this "Slash Five" i.e. "/5", to improve the 'Readability'.
        
def split(x):
    return x.split('/')[0]

# %%
#Now, "apply" this 'function' on our "rate" Column.

df_Zomato['rating'] = df_Zomato['rate'].apply(split)

# %%
#Now, Let's Check our DataFrame -
df_Zomato.head()

#Now, We will see a New Column 'rating' has been added over here where We have our exact 'rating', not like '4.1/5', not have
#any of the 'nan' Values like that.
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)    location (Processed) rating
# 0          Buffet    Banashankari  Banashankari Bangalore    4.1
# 1          Buffet    Banashankari  Banashankari Bangalore    4.1
# 2          Buffet    Banashankari  Banashankari Bangalore    3.8
# 3          Buffet    Banashankari  Banashankari Bangalore    3.7
# 4          Buffet    Banashankari  Basavanagudi Bangalore    3.8

# %%
#So again, Let's Check the "Unique" Columns on "rate" Feature.
df_Zomato['rating'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', 'NEW', '2.9', '3.5',
#        '2.6', '3.8 ', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2',
#        '2.3', '3.4 ', '-', '3.6 ', '4.8', '3.9 ', '4.2 ', '4.0 ', '4.1 ',
#        '3.7 ', '3.1 ', '2.9 ', '3.3 ', '2.8 ', '3.5 ', '2.7 ', '2.5 ',
#        '3.2 ', '2.6 ', '4.5 ', '4.3 ', '4.4 ', '4.9', '2.1', '2.0', '1.8',
#        '4.6 ', '4.9 ', '3.0 ', '4.8 ', '2.3 ', '4.7 ', '2.4 ', '2.1 ',
#        '2.2 ', '2.0 ', '1.8 '], dtype=object)

# %%
#So, Let's pre-process this data further -
    
df_Zomato['rating'].replace('NEW', 0, inplace=True)

# %%
#So, Let's pre-process this data further -
    
df_Zomato['rating'].replace('-', 0, inplace=True)

# %%
#So again, Let's Check the "Unique" Columns on "rate" Feature.
df_Zomato['rating'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', 0, '2.9', '3.5', '2.6',
#        '3.8 ', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2', '2.3',
#        '3.4 ', '3.6 ', '4.8', '3.9 ', '4.2 ', '4.0 ', '4.1 ', '3.7 ',
#        '3.1 ', '2.9 ', '3.3 ', '2.8 ', '3.5 ', '2.7 ', '2.5 ', '3.2 ',
#        '2.6 ', '4.5 ', '4.3 ', '4.4 ', '4.9', '2.1', '2.0', '1.8', '4.6 ',
#        '4.9 ', '3.0 ', '4.8 ', '2.3 ', '4.7 ', '2.4 ', '2.1 ', '2.2 ',
#        '2.0 ', '1.8 '], dtype=object)

# %%
#Now, Let's Check Data Type of this Column.
df_Zomato['rating'].dtype
# Out:
# dtype('O')

# %%
#Now, Let's Change/Convert it into "float".
    
df_Zomato['rating'] = pd.to_numeric(df_Zomato['rating'])
df_Zomato['rating']

#Now, We can see the "dtype" is 'float64'.
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51709    3.7
# 51711    2.5
# 51712    3.6
# 51715    4.3
# 51716    3.4
# Name: rating, Length: 43942, dtype: float64

# %%
#Let's fetch each and every 'Location' with "Avg. Rating".
        
df_Zomato.groupby('location (Processed)')['rating'].mean()
# Out:
# location (Processed)
# BTM Bangalore                  3.296128
# Banashankari Bangalore         3.373292
# Banaswadi Bangalore            3.362926
# Bannerghatta Road Bangalore    3.271677
# Basavanagudi Bangalore         3.478185
#                                  ...
# West Bangalore                 2.020000
# Whitefield Bangalore           3.384170
# Wilson Garden Bangalore        3.257635
# Yelahanka Bangalore            3.640000
# Yeshwantpur Bangalore          3.502679
# Name: rating, Length: 92, dtype: float64

# %%
#Now, Let's 'Sort' this Data based on the "Avg. Rating" -

df_Ratings = df_Zomato.groupby('location (Processed)')['rating'].mean().sort_values(ascending = False).reset_index()
df_Ratings.columns = ['Location', 'Avg_Rating']
df_Ratings
# Out:
#                            Location  Avg_Rating
# 0            Lavelle Road Bangalore    4.042886
# 1          St. Marks Road Bangalore    4.017201
# 2   Koramangala 3rd Block Bangalore    3.978756
# 3             Sankey Road Bangalore    3.965385
# 4           Church Street Bangalore    3.963091
# ..                              ...         ...
# 87        Electronic City Bangalore    3.041909
# 88           Bommanahalli Bangalore    2.926752
# 89                 Hebbal Bangalore    2.880000
# 90                  North Bangalore    2.385714
# 91                   West Bangalore    2.020000
#
# [92 rows x 2 columns]

# %%
#Now, Let's Create a DataFrame - 
df_Ratings_Locations = pd.DataFrame({
                            'Name' : df_Ratings['Location']
                        })
df_Ratings_Locations
# Out:
#                                Name
# 0            Lavelle Road Bangalore
# 1          St. Marks Road Bangalore
# 2   Koramangala 3rd Block Bangalore
# 3             Sankey Road Bangalore
# 4           Church Street Bangalore
# ..                              ...
# 87        Electronic City Bangalore
# 88           Bommanahalli Bangalore
# 89                 Hebbal Bangalore
# 90                  North Bangalore
# 91                   West Bangalore
#
# [92 rows x 1 columns]

# %%
#Indentify Latitudes and Logitudes for each of the Locations of Bangalore.
Lat = []
Long = []

for location in df_Ratings_Locations['Name']:
    location = geolocator.geocode(location)
    
    if location is None: 
        Lat.append(np.nan)
        Long.append(np.nan)   
    else:                      
        Lat.append(location.latitude)
        Long.append(location.longitude)

# %%
#Just Cross-Checking the Length of the 'latitudes':
print(len(Lat))
# Out:
# 92

# %%
#Just Cross-Checking the Length of the 'longitude':
print(len(Long))
# Out:
# 92

# %%
#Just Cross-Checking the 'latitude' and 'longitude' Values -
print([Lat, Long])
# Out:
# [[12.9750062, nan, 12.9271867, 13.0035092, 12.9742939, 12.928080600000001, 12.9904458, 12.9274413, 13.0530002, 15.8782951, 12.93433385, 12.957998, 12.9831774, 12.928080600000001, 12.9741854, 12.983801, 12.9176571, 12.9931876, 12.9668257, 12.9310963, 13.0027353, 12.9400321, 12.9732913, 13.1006982, 13.0101286, 12.9292731, 12.9417812, 13.2923988, 12.9750605, 13.0343483, 12.988721250000001, 12.996845, 12.9243509, 12.9778793, 13.0221416, 12.9055682, 13.02383, 13.0093455, 12.986391, 13.0464531, 12.9116225, 12.9065281, 13.0621474, 12.9417261, 12.9846713, 12.9242381, 12.9597523, 12.965717999999999, 12.9917539, 12.987027, 12.9678074, 12.9882338, 12.9172247, 12.9072515, 12.9552572, 12.95961755, 12.9592241, 12.9624669, 12.9696365, 12.9668213, 12.9152208, 13.0141618, 12.9578658, 13.0431413, 12.9575547, 12.9805381, 12.9081487, 12.93577245, 12.9414662, 12.911275849999999, 12.9757079, 13.0358698, 13.0227204, 12.8870547, 12.928080600000001, 12.9489339, 12.96595445, 12.9845687, 13.007516, 12.9855509, 13.0329419, 13.0086263, 12.9821931, nan, 12.973936, 13.0258087, 12.945245, 12.8563536, 12.9089453, 13.0382184, 12.9767936, 12.9848519], [77.5998217, nan, 77.6266252, 77.5837816, 77.6525189, 77.63071968728623, 77.5910041, 77.5155224, 77.6204833, 74.5084834, 77.63040639553275, 77.6037312, 77.595831, 77.63071968728623, 77.6124135, 77.5808654, 77.4837568, 77.5753419, 77.6096372, 77.6140388, 77.5703253, 77.6203272, 77.6404672, 77.5963454, 77.5548006, 77.5824229, 77.6160146, 77.7519261, 77.6080323, 77.5683468, 77.58516877601824, 77.6130165, 77.6255562, 77.6246697, 77.6403368, 77.5455438, 77.5529215, 77.6377094, 77.6075416, 77.5483803, 77.6388622, 77.5733344, 77.58006135480495, 77.5755021, 77.6790908, 77.6289059, 77.5561291, 77.5762705372058, 77.5383401, 77.5201369, 77.6568367, 77.554883, 77.6143995, 77.5782713, 77.6984163, 77.51126721318181, 77.6615183, 77.6381958, 77.7497448, 77.7168891, 77.573598, 77.6518539, 77.6958748, 77.6209093, 77.5979099, 77.7273032, 77.5553179, 77.66676103753434, 77.7470942, 77.60456543431182, 77.5728757, 77.6323597, 77.595715, 77.5969483, 77.63071968728623, 77.5968273, 77.61253320881664, 77.73766474151809, 77.695935, 77.668072, 77.5273253, 77.6962756, 77.6083132, nan, 77.6509982, 77.6305067, 77.6269144, 77.6636073, 77.6239038, 77.5919, 77.590082, 77.5400626]]

# %%
# Now, Add these ('Latitude' & 'Longitude') Columns to DataFrame -
df_Ratings_Locations['Latitude'] = Lat
df_Ratings_Locations['Longitude'] = Long

# %%
#Now, Let's pre-process & call our DataFrame to see What we've got -
df_Ratings_Locations.rename(columns = {'Name' : 'Location'}, inplace = True)
df_Ratings_Locations
# Out:
#                            Location   Latitude  Longitude
# 0            Lavelle Road Bangalore  12.975006  77.599822
# 1          St. Marks Road Bangalore        NaN        NaN
# 2   Koramangala 3rd Block Bangalore  12.927187  77.626625
# 3             Sankey Road Bangalore  13.003509  77.583782
# 4           Church Street Bangalore  12.974294  77.652519
# ..                              ...        ...        ...
# 87        Electronic City Bangalore  12.856354  77.663607
# 88           Bommanahalli Bangalore  12.908945  77.623904
# 89                 Hebbal Bangalore  13.038218  77.591900
# 90                  North Bangalore  12.976794  77.590082
# 91                   West Bangalore  12.984852  77.540063
#
# [92 rows x 3 columns]

# %%
#Now, Let's 'Combine'/'Merge' both our DataFrame -
    #So, Very 1st one is our "df_Ratings_Locations" and the 2nd one is our "df_Ratings".
    
df_Ratings_Final = df_Ratings_Locations.merge(right = df_Ratings, on = 'Location', how = 'left').dropna()
df_Ratings_Final
# Out:
#                            Location   Latitude  Longitude  Avg_Rating
# 0            Lavelle Road Bangalore  12.975006  77.599822    4.042886
# 2   Koramangala 3rd Block Bangalore  12.927187  77.626625    3.978756
# 3             Sankey Road Bangalore  13.003509  77.583782    3.965385
# 4           Church Street Bangalore  12.974294  77.652519    3.963091
# 5   Koramangala 5th Block Bangalore  12.928081  77.630720    3.901512
# ..                              ...        ...        ...         ...
# 87        Electronic City Bangalore  12.856354  77.663607    3.041909
# 88           Bommanahalli Bangalore  12.908945  77.623904    2.926752
# 89                 Hebbal Bangalore  13.038218  77.591900    2.880000
# 90                  North Bangalore  12.976794  77.590082    2.385714
# 91                   West Bangalore  12.984852  77.540063    2.020000
#
# [90 rows x 4 columns]

# %%
#Q5. Create a HeatMap to Analyse - What are those Restaurants that have "Highest Ratings"?

HeatMap(df_Ratings_Final[['Latitude', 'Longitude', 'Avg_Rating']]).add_to(baseMap)

# %%
#Now, just call our "baseMap".
baseMap

#So, from this Visualization, we can see All the Restaurants are Located over here.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_764405d847314ca7aa3cc797d00e3c90%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20 ...

# %% [markdown]
# **Conclusion -**
# - This is exactly our ***beautiful 'baseMap'*** over here.
# - We will see here in this **"Central Bangalore Area"**, we have **"Highest Density"**.
# - It means, in this ***Zone/Region***, We have **"Maximum Number of Restaurants"** that are having **"Highest Ratings"**.
# - That's ***How exactly we can 'make inference' from our "Special Visuals"***.

# %%
df_Zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)    location (Processed)  rating
# 0          Buffet    Banashankari  Banashankari Bangalore     4.1
# 1          Buffet    Banashankari  Banashankari Bangalore     4.1
# 2          Buffet    Banashankari  Banashankari Bangalore     3.8
# 3          Buffet    Banashankari  Banashankari Bangalore     3.7
# 4          Buffet    Banashankari  Basavanagudi Bangalore     3.8

# %%
#Q6. HeatMap of North Indian Restaurants.

#Now, Let's check "unique" cuisines -
df_Zomato['cuisines'].unique()
# Out:
# array(['North Indian, Mughlai, Chinese', 'Chinese, North Indian, Thai',
#        'Cafe, Mexican, Italian', ..., 'Tibetan, Nepalese',
#        'North Indian, Street Food, Biryani',
#        'North Indian, Chinese, Arabian, Momos'], dtype=object)

# %%
#Next, Let's put a Condition as "cuisines" equal equals to "North Indian".

df_North_Indian_Cuisines = df_Zomato[df_Zomato['cuisines'] == 'North Indian']
df_North_Indian_Cuisines.head()
# Out:
#                                                   url  \
# 5   https://www.zomato.com/bangalore/timepass-dinn...
# 50  https://www.zomato.com/bangalore/petoo-banasha...
# 72  https://www.zomato.com/bangalore/spicy-tandoor...
# 87  https://www.zomato.com/bangalore/krishna-sagar...
# 94  https://www.zomato.com/bangalore/nandhini-delu...
#
#                                               address             name  \
# 5   37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...  Timepass Dinner
# 50  276, Ground Floor, 100 Feet Outer Ring Road, B...            Petoo
# 72  Opposite ICICi Bank, Hanuman Nagar, Banashanka...    Spicy Tandoor
# 87  38, 22nd Main, 22nd Cross, Opposite BDA, 2nd S...    Krishna Sagar
# 94  304, Opposite Apollo Public School, 100 Feet R...  Nandhini Deluxe
#
#    online_order book_table   rate  votes                             phone  \
# 5           Yes         No  3.8/5    286  +91 9980040002\r\n+91 9980063005
# 50           No         No  3.7/5     21                    +91 8026893211
# 72           No         No    NEW      0                    +91 8050884222
# 87           No         No  3.5/5     31  +91 8892752997\r\n+91 7204780429
# 94           No         No  2.6/5    283      080 26890011\r\n080 26890033
#
#         location      rest_type  \
# 5   Basavanagudi  Casual Dining
# 50  Banashankari    Quick Bites
# 72  Banashankari    Quick Bites
# 87  Banashankari    Quick Bites
# 94  Banashankari  Casual Dining
#
#                                            dish_liked      cuisines  \
# 5   Onion Rings, Pasta, Kadhai Paneer, Salads, Sal...  North Indian
# 50                                                NaN  North Indian
# 72                                                NaN  North Indian
# 87                                                NaN  North Indian
# 94  Biryani, Chicken Guntur, Thali, Buttermilk, Ma...  North Indian
#
#    approx_cost(for two people)  \
# 5                          600
# 50                         450
# 72                         150
# 87                         200
# 94                         600
#
#                                          reviews_list menu_item  \
# 5   [('Rated 3.0', 'RATED\n  Food 3/5\nAmbience 3/...        []
# 50  [('Rated 2.0', 'RATED\n  This is a neatly made...        []
# 72  [('Rated 4.0', 'RATED\n  cost for chicken roll...        []
# 87  [('Rated 1.0', 'RATED\n  Worst experience with...        []
# 94  [('Rated 3.0', 'RATED\n  Ididnt like much.\n\n...        []
#
#    listed_in(type) listed_in(city)    location (Processed)  rating
# 5           Buffet    Banashankari  Basavanagudi Bangalore     3.8
# 50        Delivery    Banashankari  Banashankari Bangalore     3.7
# 72        Delivery    Banashankari  Banashankari Bangalore     0.0
# 87        Delivery    Banashankari  Banashankari Bangalore     3.5
# 94        Delivery    Banashankari  Banashankari Bangalore     2.6

# %%
#Now, Let's get the Locations with Total Number of Restaurants -

df_North_Indian_Cuisines = df_North_Indian_Cuisines.groupby('location (Processed)')['name'].agg('count').reset_index()
df_North_Indian_Cuisines
# Out:
#                        location (Processed)  name
# 0                             BTM Bangalore   274
# 1                    Banashankari Bangalore    35
# 2                       Banaswadi Bangalore     9
# 3               Bannerghatta Road Bangalore    60
# 4                    Basavanagudi Bangalore    17
# ..                                      ...   ...
# 59  Varthur Main Road, Whitefield Bangalore     3
# 60                  Vasanth Nagar Bangalore    12
# 61                     Whitefield Bangalore   148
# 62                  Wilson Garden Bangalore    37
# 63                    Yeshwantpur Bangalore     3
#
# [64 rows x 2 columns]

# %%
#Now, Let's "pre-process" and "Sort" this DataFrame as well -
df_North_Indian_Cuisines.columns = ['Name', 'Count']
df_North_Indian_Cuisines.sort_values(by = 'Count', ascending = False, inplace = True)
df_North_Indian_Cuisines
# Out:
#                             Name  Count
# 0                  BTM Bangalore    274
# 61          Whitefield Bangalore    148
# 24            JP Nagar Bangalore    135
# 19                 HSR Bangalore    131
# 6            Bellandur Bangalore    131
# ..                           ...    ...
# 20              Hennur Bangalore      2
# 46            RT Nagar Bangalore      2
# 14                East Bangalore      2
# 44               North Bangalore      1
# 5   Basaveshwara Nagar Bangalore      1
#
# [64 rows x 2 columns]

# %%
#Now, Let's 'Combine'/'Merge' both my DataFrame -
    
df_North_Indian_Final = df_North_Indian_Cuisines.merge(right = df_locations, on = 'Name', how = 'left').dropna()
df_North_Indian_Final
# Out:
#                             Name  Count   Latitude  Longitude
# 0                  BTM Bangalore    274  12.911276  77.604565
# 1           Whitefield Bangalore    148  12.969637  77.749745
# 2             JP Nagar Bangalore    135  12.907251  77.578271
# 3                  HSR Bangalore    131  12.911623  77.638862
# 4            Bellandur Bangalore    131  12.935772  77.666761
# ..                           ...    ...        ...        ...
# 59              Hennur Bangalore      2  13.025809  77.630507
# 60            RT Nagar Bangalore      2  13.022720  77.595715
# 61                East Bangalore      2  12.984569  77.737665
# 62               North Bangalore      1  12.976794  77.590082
# 63  Basaveshwara Nagar Bangalore      1  12.991754  77.538340
#
# [64 rows x 4 columns]

# %%
# Q6. HeatMap of North Indian Restaurants.

HeatMap(df_North_Indian_Final[['Latitude', 'Longitude', 'Count']], zoom = 20).add_to(baseMap)

# %%
#So, just call our "baseMap".
baseMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_764405d847314ca7aa3cc797d00e3c90%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20 ...

# %% [markdown]
# **Conclusion -** **"HeatMap"** of **"North Indian Restaurants"** in ***Bangalore***.
# - From this **HeatMap**, we can come to a ***Conclusion*** that, In **"South-East" Bangalore Region**, We have **"Maximum Number of North Indian Restaurants"**.
# - So, We can also **Conclude** that, again in this Zone, We might have a **"Maximum Number of North Indian People"**.

# %%
def HeatMap_Zone(zone):
    df_Zone = df_Zomato[df_Zomato['cuisines'] == zone]
    df_Zone = df_Zone.groupby('location (Processed)')['name'].agg('count').reset_index()
    df_Zone.columns = ['Name', 'Count']
    df_Zone.sort_values(by = 'Count', ascending = False, inplace = True)
    df_Zone = df_Zone.merge(right = df_locations, on = 'Name', how = 'left').dropna()
    HeatMap(df_Zone[['Latitude', 'Longitude', 'Count']], zoom = 20).add_to(baseMap)
    return baseMap

# %%
#Now, Let's check "unique" cuisines -
df_Zomato['cuisines'].unique()
# Out:
# array(['North Indian, Mughlai, Chinese', 'Chinese, North Indian, Thai',
#        'Cafe, Mexican, Italian', ..., 'Tibetan, Nepalese',
#        'North Indian, Street Food, Biryani',
#        'North Indian, Chinese, Arabian, Momos'], dtype=object)

# %%
# Q7. HeatMap of "South Indian" cuisines Restaurants.

HeatMap_Zone('South Indian')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_764405d847314ca7aa3cc797d00e3c90%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20 ...

# %% [markdown]
# **Conclusion -** **"HeatMap"** of **"South Indian Restaurants"** in ***Bangalore***.
# - From this **HeatMap**, we can come to a ***Conclusion*** that, In **"South-West" Bangalore Region**, We have **"Maximum Number of "South Indian Restaurants"** followed by **"Central"** and **"South-East" Bangalore**.
# - So, We can also **Conclude** that, again in this Zone, We might have a **"Maximum Number of South Indian People"**.
# - So, that's a basically a Conclusion of this Visualization or a **HeatMap**.

# %%
# Q8. HeatMap of "Biryani" cuisines Restaurants.

HeatMap_Zone('Biryani')

folium.TileLayer('Stamen Terrain').add_to(baseMap)
folium.TileLayer('Stamen Toner').add_to(baseMap)
folium.TileLayer('Stamen Water Color').add_to(baseMap)
folium.TileLayer('cartodbpositron').add_to(baseMap)
folium.TileLayer('cartodbdark_matter').add_to(baseMap)
folium.LayerControl().add_to(baseMap)
baseMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_764405d847314ca7aa3cc797d00e3c90%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20 ...

# %% [markdown]
# **Conclusion -** **"HeatMap"** of **"Biryani" cuisines Restaurants"** in ***Bangalore***.
# - From this **HeatMap**, we can come to a ***Conclusion*** that, In **"South" Bangalore Region**, We have **"Maximum Number of "Biryani cuisines Restaurants"** followed by **"South-West"** and **"Central" Bangalore**.
# - So, that's a basically a Conclusion of this Visualization or a **HeatMap**.
